# %%
# !pip install numpy
# !pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 100000
U=np.random.uniform(0,1,N)

x = np.log((np.exp(2)-1)*U+1)

print(x)

X=np.arange(0, 2, 0.1)
fx=np.exp(X)/(np.exp(2)-1)
plt.plot(X,fx)
plt.hist(x,bins=100,density=True)
plt.show()
# Out:
# [0.78159725 1.30471476 0.51274921 ... 1.34982955 1.12913479 1.85058395]
